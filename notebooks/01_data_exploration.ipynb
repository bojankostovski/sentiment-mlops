# %%
# Install dependencies
# !pip install torch torchtext pandas matplotlib seaborn

import torch
from torchtext.datasets import IMDB
from torchtext.data.utils import get_tokenizer
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt

# Load IMDB dataset
train_iter, test_iter = IMDB(split=('train', 'test'))

# Explore data
print("Dataset loaded!")
print(f"Training samples: {len(list(IMDB(split='train')))}")
print(f"Test samples: {len(list(IMDB(split='test')))}")

# Sample review
for label, text in IMDB(split='train'):
    print(f"Label: {label}")
    print(f"Text: {text[:200]}...")
    break

# Analyze distribution
labels = [label for label, text in IMDB(split='train')]
pd.Series(labels).value_counts().plot(kind='bar', title='Label Distribution')
plt.savefig('../docs/label_distribution.png')
